# %% [markdown]
# # 00 — Environment Check
#
# This notebook verifies that the project environment is ready.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import torch

print('Python:', sys.version)
print('NumPy:', np.__version__)
print('Pandas:', pd.__version__)
print('Matplotlib:', matplotlib.__version__)
print('Scikit-learn:', sklearn.__version__)
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
# Out:
# Python: 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# NumPy: 2.5.1
# Pandas: 3.0.3
# Matplotlib: 3.11.0
# Scikit-learn: 1.9.0
# PyTorch: 2.12.1+cpu
# CUDA available: False

# %% [markdown]
# ## Expected result
#
# All imports should run without errors. CUDA may be `False`; CPU is sufficient for the first version.
